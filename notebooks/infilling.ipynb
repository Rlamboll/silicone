# %% [markdown]
# # Infilling
#
# In this notebook we demonstrate Silicone's infilling methods.

# %% [markdown]
# ## Imports

# %%
# NBVAL_IGNORE_OUTPUT
import os.path
import traceback

import pandas as pd
import pyam
import matplotlib.pyplot as plt
import numpy as np

import silicone.database_crunchers

# %% [markdown]
# ## Constants

# %%
SR15_SCENARIOS = "./sr15_scenarios.csv"

# %% [markdown]
# ## Example data
#
# Here we pull some example data by downloading a selection of the SR1.5 scenarios.

# %%
def get_sr15_scenarios(output_file):
    conn = pyam.iiasa.Connection("iamc15")
    valid_model_ids = [
        "MESSAGE*",
        "AIM*",
        "C-ROADS*",
        "GCAM*",
        #"IEA*",
        #"IMAGE*",
        #"MERGE*",
        #"POLES*",
        #"REMIND*",
        "WITCH*"
    ]
    variables_to_fetch = [
        "Emissions*",
    ]
    for model in valid_model_ids:
        print("Fetching data for {}".format(model))
        for variable in variables_to_fetch:
            print("Fetching {}".format(variable))
            var_df = conn.query(model=model, variable=variable, region='World')
            try:
                df.append(var_df, inplace=True)
            except NameError:
                df = pyam.IamDataFrame(var_df)

    print("Writing to {}".format(output_file))
    df.to_csv(output_file)

# %%
# NBVAL_IGNORE_OUTPUT
if not os.path.isfile(SR15_SCENARIOS):
    get_sr15_scenarios(SR15_SCENARIOS)

# %% [markdown]
# ### Starting point
#
# Our starting point is the test data, loaded a `pyam.IamDataFrame`.

# %%
# NBVAL_IGNORE_OUTPUT
sr15_data = pyam.IamDataFrame(SR15_SCENARIOS)
sr15_data.timeseries().head()
# Out:
# INFO:root:Reading `./sr15_scenarios.csv`
#                                                                                                         2000  \
# model       scenario               region variable                                           unit
# AIM/CGE 2.0 ADVANCE_2020_1.5C-2100 World  Emissions|BC                                       Mt BC/yr    NaN
#                                           Emissions|CH4                                      Mt CH4/yr   NaN
#                                           Emissions|CH4|AFOLU                                Mt CH4/yr   NaN
#                                           Emissions|CH4|Energy|Demand|Industry               Mt CH4/yr   NaN
#                                           Emissions|CH4|Energy|Demand|Residential and Com... Mt CH4/yr   NaN
#
#                                                                                                             2005  \
# model       scenario               region variable                                           unit
# AIM/CGE 2.0 ADVANCE_2020_1.5C-2100 World  Emissions|BC                                       Mt BC/yr     8.3367
#                                           Emissions|CH4                                      Mt CH4/yr  344.9167
#                                           Emissions|CH4|AFOLU                                Mt CH4/yr  167.6717
#                                           Emissions|CH4|Energy|Demand|Industry               Mt CH4/yr    0.4732
#                                           Emissions|CH4|Energy|Demand|Residential and Com... Mt CH4/yr   11.2639
#
#                                                                                                             2010  \
# model       scenario               region variable                                           unit
# AIM/CGE 2.0 ADVANCE_2020_1.5C-2100 World  Emissions|BC                                       Mt BC/yr     7.6408
#                                           Emissions|CH4                                      Mt CH4/yr  367.7457
#                                           Emissions|CH4|AFOLU                                Mt CH4/yr  179.6356
#                                           Emissions|CH4|Energy|Demand|Industry               Mt CH4/yr    0.5168
#                                           Emissions|CH4|Energy|Demand|Residential and Com... Mt CH4/yr   11.1249
#
#                                                                                                         2014  \
# model       scenario               region variable                                           unit
# AIM/CGE 2.0 ADVANCE_2020_1.5C-2100 World  Emissions|BC                                       Mt BC/yr    NaN
#                                           Emissions|CH4                                      Mt CH4/yr   NaN
#                                           Emissions|CH4|AFOLU                                Mt CH4/yr   NaN
#                                           Emissions|CH4|Energy|Demand|Industry               Mt CH4/yr   NaN
#                                           Emissions|CH4|Energy|Demand|Residential and Com... Mt CH4/yr   NaN
#
#                                                                                                             2015  \
# model       scenario               region variable                                           unit
# AIM/CGE 2.0 ADVANCE_2020_1.5C-2100 World  Emissions|BC                                       Mt BC/yr     7.2724
#                                           Emissions|CH4                                      Mt CH4/yr  380.4086
#                                           Emissions|CH4|AFOLU                                Mt CH4/yr  190.3513
#                                           Emissions|CH4|Energy|Demand|Industry               Mt CH4/yr    0.5587
#                                           Emissions|CH4|Energy|Demand|Residential and Com... Mt CH4/yr   10.9809
#
#                                                                                                             2020  \
# model       scenario               region variable                                           unit
# AIM/CGE 2.0 ADVANCE_2020_1.5C-2100 World  Emissions|BC                                       Mt BC/yr     7.0752
#                                           Emissions|CH4                                      Mt CH4/yr  385.0877
#                                           Emissions|CH4|AFOLU                                Mt CH4/yr  198.5217
#                                           Emissions|CH4|Energy|Demand|Industry               Mt CH4/yr    0.6040
#                                           Emissions|CH4|Energy|Demand|Residential and Com... Mt CH4/yr   10.8317
#
#                                                                                                             2025  \
# model       scenario               region variable                                           unit
# AIM/CGE 2.0 ADVANCE_2020_1.5C-2100 World  Emissions|BC                                       Mt BC/yr     5.8486
#                                           Emissions|CH4                                      Mt CH4/yr  229.1313
#                                           Emissions|CH4|AFOLU                                Mt CH4/yr  152.3684
#                                           Emissions|CH4|Energy|Demand|Industry               Mt CH4/yr    0.5722
#                                           Emissions|CH4|Energy|Demand|Residential and Com... Mt CH4/yr   10.3109
#
#                                                                                                             2030  \
# model       scenario               region variable                                           unit
# AIM/CGE 2.0 ADVANCE_2020_1.5C-2100 World  Emissions|BC                                       Mt BC/yr     5.2890
#                                           Emissions|CH4                                      Mt CH4/yr  182.2792
#                                           Emissions|CH4|AFOLU                                Mt CH4/yr  129.2881
#                                           Emissions|CH4|Energy|Demand|Industry               Mt CH4/yr    0.5295
#                                           Emissions|CH4|Energy|Demand|Residential and Com... Mt CH4/yr    9.4546
#
#                                                                                                             2035  \
# model       scenario               region variable                                           unit
# AIM/CGE 2.0 ADVANCE_2020_1.5C-2100 World  Emissions|BC                                       Mt BC/yr     4.7920
#                                           Emissions|CH4                                      Mt CH4/yr  155.2220
#                                           Emissions|CH4|AFOLU                                Mt CH4/yr  115.4458
#                                           Emissions|CH4|Energy|Demand|Industry               Mt CH4/yr    0.4992
#                                           Emissions|CH4|Energy|Demand|Residential and Com... Mt CH4/yr    8.6100
#
#                                                                                                             2040  \
# model       scenario               region variable                                           unit
# AIM/CGE 2.0 ADVANCE_2020_1.5C-2100 World  Emissions|BC                                       Mt BC/yr     4.4694
#                                           Emissions|CH4                                      Mt CH4/yr  133.4843
#                                           Emissions|CH4|AFOLU                                Mt CH4/yr  103.5424
#                                           Emissions|CH4|Energy|Demand|Industry               Mt CH4/yr    0.4915
#                                           Emissions|CH4|Energy|Demand|Residential and Com... Mt CH4/yr    7.8718
#
#                                                                                                         ...  \
# model       scenario               region variable                                           unit       ...
# AIM/CGE 2.0 ADVANCE_2020_1.5C-2100 World  Emissions|BC                                       Mt BC/yr   ...
#                                           Emissions|CH4                                      Mt CH4/yr  ...
#                                           Emissions|CH4|AFOLU                                Mt CH4/yr  ...
#                                           Emissions|CH4|Energy|Demand|Industry               Mt CH4/yr  ...
#                                           Emissions|CH4|Energy|Demand|Residential and Com... Mt CH4/yr  ...
#
#                                                                                                             2055  \
# model       scenario               region variable                                           unit
# AIM/CGE 2.0 ADVANCE_2020_1.5C-2100 World  Emissions|BC                                       Mt BC/yr     3.4700
#                                           Emissions|CH4                                      Mt CH4/yr  107.6389
#                                           Emissions|CH4|AFOLU                                Mt CH4/yr   88.7903
#                                           Emissions|CH4|Energy|Demand|Industry               Mt CH4/yr    0.5689
#                                           Emissions|CH4|Energy|Demand|Residential and Com... Mt CH4/yr    6.3824
#
#                                                                                                             2060  \
# model       scenario               region variable                                           unit
# AIM/CGE 2.0 ADVANCE_2020_1.5C-2100 World  Emissions|BC                                       Mt BC/yr     3.3654
#                                           Emissions|CH4                                      Mt CH4/yr  111.0836
#                                           Emissions|CH4|AFOLU                                Mt CH4/yr   92.3224
#                                           Emissions|CH4|Energy|Demand|Industry               Mt CH4/yr    0.6136
#                                           Emissions|CH4|Energy|Demand|Residential and Com... Mt CH4/yr    5.9928
#
#                                                                                                             2065  \
# model       scenario               region variable                                           unit
# AIM/CGE 2.0 ADVANCE_2020_1.5C-2100 World  Emissions|BC                                       Mt BC/yr     3.2515
#                                           Emissions|CH4                                      Mt CH4/yr  115.9752
#                                           Emissions|CH4|AFOLU                                Mt CH4/yr   96.7759
#                                           Emissions|CH4|Energy|Demand|Industry               Mt CH4/yr    0.6628
#                                           Emissions|CH4|Energy|Demand|Residential and Com... Mt CH4/yr    5.6423
#
#                                                                                                             2070  \
# model       scenario               region variable                                           unit
# AIM/CGE 2.0 ADVANCE_2020_1.5C-2100 World  Emissions|BC                                       Mt BC/yr     3.1251
#                                           Emissions|CH4                                      Mt CH4/yr  116.5906
#                                           Emissions|CH4|AFOLU                                Mt CH4/yr   98.0924
#                                           Emissions|CH4|Energy|Demand|Industry               Mt CH4/yr    0.7011
#                                           Emissions|CH4|Energy|Demand|Residential and Com... Mt CH4/yr    5.2548
#
#                                                                                                             2075  \
# model       scenario               region variable                                           unit
# AIM/CGE 2.0 ADVANCE_2020_1.5C-2100 World  Emissions|BC                                       Mt BC/yr     3.0047
#                                           Emissions|CH4                                      Mt CH4/yr  118.0872
#                                           Emissions|CH4|AFOLU                                Mt CH4/yr  100.5173
#                                           Emissions|CH4|Energy|Demand|Industry               Mt CH4/yr    0.6871
#                                           Emissions|CH4|Energy|Demand|Residential and Com... Mt CH4/yr    4.8423
#
#                                                                                                             2080  \
# model       scenario               region variable                                           unit
# AIM/CGE 2.0 ADVANCE_2020_1.5C-2100 World  Emissions|BC                                       Mt BC/yr     2.9706
#                                           Emissions|CH4                                      Mt CH4/yr  120.9023
#                                           Emissions|CH4|AFOLU                                Mt CH4/yr  103.2884
#                                           Emissions|CH4|Energy|Demand|Industry               Mt CH4/yr    0.7002
#                                           Emissions|CH4|Energy|Demand|Residential and Com... Mt CH4/yr    4.5313
#
#                                                                                                             2085  \
# model       scenario               region variable                                           unit
# AIM/CGE 2.0 ADVANCE_2020_1.5C-2100 World  Emissions|BC                                       Mt BC/yr     2.9239
#                                           Emissions|CH4                                      Mt CH4/yr  122.0036
#                                           Emissions|CH4|AFOLU                                Mt CH4/yr  104.7226
#                                           Emissions|CH4|Energy|Demand|Industry               Mt CH4/yr    0.7086
#                                           Emissions|CH4|Energy|Demand|Residential and Com... Mt CH4/yr    4.2217
#
#                                                                                                             2090  \
# model       scenario               region variable                                           unit
# AIM/CGE 2.0 ADVANCE_2020_1.5C-2100 World  Emissions|BC                                       Mt BC/yr     2.8850
#                                           Emissions|CH4                                      Mt CH4/yr  120.1977
#                                           Emissions|CH4|AFOLU                                Mt CH4/yr  103.9322
#                                           Emissions|CH4|Energy|Demand|Industry               Mt CH4/yr    0.7063
#                                           Emissions|CH4|Energy|Demand|Residential and Com... Mt CH4/yr    3.9025
#
#                                                                                                             2095  \
# model       scenario               region variable                                           unit
# AIM/CGE 2.0 ADVANCE_2020_1.5C-2100 World  Emissions|BC                                       Mt BC/yr     2.5998
#                                           Emissions|CH4                                      Mt CH4/yr  133.5733
#                                           Emissions|CH4|AFOLU                                Mt CH4/yr  114.1118
#                                           Emissions|CH4|Energy|Demand|Industry               Mt CH4/yr    0.7735
#                                           Emissions|CH4|Energy|Demand|Residential and Com... Mt CH4/yr    3.7682
#
#                                                                                                             2100
# model       scenario               region variable                                           unit
# AIM/CGE 2.0 ADVANCE_2020_1.5C-2100 World  Emissions|BC                                       Mt BC/yr     2.5771
#                                           Emissions|CH4                                      Mt CH4/yr  133.5872
#                                           Emissions|CH4|AFOLU                                Mt CH4/yr  114.5658
#                                           Emissions|CH4|Energy|Demand|Industry               Mt CH4/yr    0.7577
#                                           Emissions|CH4|Energy|Demand|Residential and Com... Mt CH4/yr    3.5064
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Crunchers
#
# Silicone's 'crunchers' are used to determine the relationship between a 'follower variable' and 'lead variable(s)' from a given database. The 'follower variable' is the variable for which we want to generate data e.g. `Emissions|C3F8` while the 'lead variable(s)' is the variable we want to use in order to infer a timeseries of the 'follower variable'. The lead variable is typically CO$_2$ but might be a more complex combination of gases e.g. CO$_2$, CH$_4$ and N$_2$O.
#
# Each cruncher has a `derive_relationship` method. Its docstring describes what it does.

# %%
print(silicone.database_crunchers.base._DatabaseCruncher.derive_relationship.__doc__)
# # an alternative interface is shown if you use the line below instead
# silicone.database_crunchers.base._DatabaseCruncher.derive_relationship?
# Out:
#         Derive the relationship between two variables from the database
#
#         Parameters
#         ----------
#         variable_follower : str
#             The variable for which we want to calculate timeseries (e.g.
#             ``"Emissions|C5F12"``).
#
#         variable_leaders : list[str]
#             The variables we want to use in order to infer timeseries of
#             ``variable_follower`` (e.g. ``["Emissions|CO2", "Emissions|CH4"]``)
#
#         **kwargs
#             Keyword arguments used by this class to derive the relationship between
#             ``variable_follower`` and ``variable_leaders``.
#
#         Returns
#         -------
#         :obj:`func`
#             Function which takes a :obj:`pyam.IamDataFrame` containing
#             ``variable_leaders`` timeseries and returns timeseries for
#             ``variable_follower`` based on the derived relationship between the two.
#             Please see the source code for the exact definition (and docstring) of the
#             returned function.

# %% [markdown]
# These crunchers are best explored by looking at the examples below.

# %% [markdown]
# ### Closest RMS cruncher
#
# This cruncher uses the 'closest RMS' methodology. It is described by its docstring.

# %%
print(silicone.database_crunchers.DatabaseCruncherRMSClosest.__doc__)
# silicone.database_crunchers.DatabaseCruncherRMSClosest?
# Out:
#     Database cruncher which uses the 'closest RMS' technkque.
#
#     This cruncher derives the relationship between two variables by finding the
#     scenario which has the closest lead gas timeseries in the database.  The follower
#     gas timeseries is then simply copied from the closest scenario.
#
#     Here, 'closest' is defined as the smallest time-averaged root mean squared (L2)
#     difference.
#
#     .. math::
#         RMS = \left ( \frac{1}{n} \sum_{t=0}^n (E_l(t) - E_l^{d}(t))^2 \right )^{1/2}
#
#     where :math:`n` is the total number of timesteps in the lead gas' timeseries,
#     :math:`E_l(t)` is the lead gas emissions timeseries and :math:`E_l^d(t)` is a lead
#     gas emissions timeseries in the database.

# %% [markdown]
# #### Infilling

# %% [markdown]
# Firstly, let's cut the database down to a size that is comprehensible.

# %%
# NBVAL_IGNORE_OUTPUT
sr15_data_closest_rms = sr15_data.filter(model=["WITCH-GLOBIOM 4.2"])

# %% [markdown]
# Now we can crunch the relationship between e.g. `Emissions|CO2` and `Emissions|VOC`.

# %%
# NBVAL_IGNORE_OUTPUT
cruncher = silicone.database_crunchers.DatabaseCruncherRMSClosest(sr15_data_closest_rms)

# %%
filler = cruncher.derive_relationship("Emissions|VOC", ["Emissions|CO2"])
print(filler.__doc__)
# filler info:
# Out:
#             Filler function derived from :obj:`DatabaseCruncherRMSClosest`.
#
#             Parameters
#             ----------
#             in_iamdf : :obj:`pyam.IamDataFrame`
#                 Input data to fill data in
#
#             Returns
#             -------
#             :obj:`pyam.IamDataFrame`
#                 Filled in data (without original source data)
#
#             Raises
#             ------
#             ValueError
#                 If there are any inconsistencies between the timeseries, units or
#                 expectations of the program and ``in_iamdf``, compared to the database
#                 used to generate this ``filler`` function.

# %% [markdown]
# Now we can do some infilling. As a sanity check, we firstly make sure that if we pass in a CO$_2$ timeseries which is already in the database, we get back its VOC emissions timeseries.

# %%
example_model_scen = {
    "model": "WITCH-GLOBIOM 4.2",
    "scenario": "ADVANCE_INDC",
}
example_input = sr15_data_closest_rms.filter(**example_model_scen).data
example_input["model"] = "example"
example_input["scenario"] = "example"
example_input = pyam.IamDataFrame(example_input)

# %%
# NBVAL_IGNORE_OUTPUT
example_input_filled = filler(example_input)

# %%
#NBVAL_IGNORE_OUTPUT
example_input_filled.timeseries()
# Out:
#                                                     2005        2010  \
# model   scenario region variable      unit
# example example  World  Emissions|VOC Mt VOC/yr  189.212  164.056724
#
#                                                        2015        2020  \
# model   scenario region variable      unit
# example example  World  Emissions|VOC Mt VOC/yr  153.575866  145.611005
#
#                                                        2025        2030  \
# model   scenario region variable      unit
# example example  World  Emissions|VOC Mt VOC/yr  130.387433  115.465871
#
#                                                        2035       2040  \
# model   scenario region variable      unit
# example example  World  Emissions|VOC Mt VOC/yr  102.038923  89.302542
#
#                                                      2045       2050  \
# model   scenario region variable      unit
# example example  World  Emissions|VOC Mt VOC/yr  76.60488  62.855685
#
#                                                       2055       2060  \
# model   scenario region variable      unit
# example example  World  Emissions|VOC Mt VOC/yr  58.440154  56.971497
#
#                                                       2065       2070  \
# model   scenario region variable      unit
# example example  World  Emissions|VOC Mt VOC/yr  55.075327  53.101911
#
#                                                       2075       2080  \
# model   scenario region variable      unit
# example example  World  Emissions|VOC Mt VOC/yr  51.074418  49.558506
#
#                                                       2085       2090  \
# model   scenario region variable      unit
# example example  World  Emissions|VOC Mt VOC/yr  47.602518  45.377459
#
#                                                      2095       2100
# model   scenario region variable      unit
# example example  World  Emissions|VOC Mt VOC/yr  43.08547  41.400122

# %%
#NBVAL_IGNORE_OUTPUT
sr15_data_closest_rms.filter(variable="Emissions|VOC", **example_model_scen).timeseries()
# Out:
#                                                                   2005  \
# model             scenario     region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_INDC World  Emissions|VOC Mt VOC/yr  189.212
#
#                                                                      2010  \
# model             scenario     region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_INDC World  Emissions|VOC Mt VOC/yr  164.056724
#
#                                                                      2015  \
# model             scenario     region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_INDC World  Emissions|VOC Mt VOC/yr  153.575866
#
#                                                                      2020  \
# model             scenario     region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_INDC World  Emissions|VOC Mt VOC/yr  145.611005
#
#                                                                      2025  \
# model             scenario     region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_INDC World  Emissions|VOC Mt VOC/yr  130.387433
#
#                                                                      2030  \
# model             scenario     region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_INDC World  Emissions|VOC Mt VOC/yr  115.465871
#
#                                                                      2035  \
# model             scenario     region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_INDC World  Emissions|VOC Mt VOC/yr  102.038923
#
#                                                                     2040  \
# model             scenario     region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_INDC World  Emissions|VOC Mt VOC/yr  89.302542
#
#                                                                    2045  \
# model             scenario     region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_INDC World  Emissions|VOC Mt VOC/yr  76.60488
#
#                                                                     2050  \
# model             scenario     region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_INDC World  Emissions|VOC Mt VOC/yr  62.855685
#
#                                                                     2055  \
# model             scenario     region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_INDC World  Emissions|VOC Mt VOC/yr  58.440154
#
#                                                                     2060  \
# model             scenario     region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_INDC World  Emissions|VOC Mt VOC/yr  56.971497
#
#                                                                     2065  \
# model             scenario     region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_INDC World  Emissions|VOC Mt VOC/yr  55.075327
#
#                                                                     2070  \
# model             scenario     region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_INDC World  Emissions|VOC Mt VOC/yr  53.101911
#
#                                                                     2075  \
# model             scenario     region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_INDC World  Emissions|VOC Mt VOC/yr  51.074418
#
#                                                                     2080  \
# model             scenario     region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_INDC World  Emissions|VOC Mt VOC/yr  49.558506
#
#                                                                     2085  \
# model             scenario     region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_INDC World  Emissions|VOC Mt VOC/yr  47.602518
#
#                                                                     2090  \
# model             scenario     region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_INDC World  Emissions|VOC Mt VOC/yr  45.377459
#
#                                                                    2095  \
# model             scenario     region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_INDC World  Emissions|VOC Mt VOC/yr  43.08547
#
#                                                                     2100
# model             scenario     region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_INDC World  Emissions|VOC Mt VOC/yr  41.400122

# %% [markdown]
# As expected, the cruncher has picked out the scenario which matches and returned its VOC timeseries. This can also be seen in a plot.

# %%
# NBVAL_IGNORE_OUTPUT
pkwargs = {"color": "scenario", "linewidth": 2}

fig = plt.figure(figsize=(16, 9))
ax = fig.add_subplot(121)
sr15_data_closest_rms.filter(variable="*CO2").line_plot(ax=ax, **pkwargs)
# sr15_data_closest_rms.filter(variable="*CO2", **example_model_scen).line_plot(ax=ax, color="black")
example_input.filter(variable="*CO2").line_plot(ax=ax, color="black", linestyle="--", dashes=(10, 15))
ax.set_title("Database CO$_2$ and lead emissions timeseries")

ax = fig.add_subplot(122)
sr15_data_closest_rms.filter(variable="*VOC").line_plot(ax=ax, **pkwargs)
example_input_filled.filter(variable="*VOC").line_plot(ax=ax, color="black", linestyle="--", dashes=(10, 15))
ax.set_title("Database VOC and filled follower emissions timeseries")

plt.tight_layout()

# %% [markdown]
# Now we can use our filler to infill other timeseries.

# %%
filler_input = sr15_data.filter(model="MESSAGEix-GLOBIOM 1.0", scenario="CD-LINKS_NPi2020_1600")

# %% [markdown]
# This scenario is missing `Emissions|VOC`.

# %%
#NBVAL_IGNORE_OUTPUT
filler_input.filter(variable="Emissions|VOC").data
# Out:
# WARNING:root:Filtered IamDataFrame is empty!
# Empty DataFrame
# Columns: [model, scenario, region, variable, unit, year, value]
# Index: []

# %%
filler_input_filled = filler(filler_input)

# %%
# NBVAL_IGNORE_OUTPUT
pkwargs = {"color": "scenario", "linewidth": 2}

fig = plt.figure(figsize=(16, 9))
ax = fig.add_subplot(121)
sr15_data_closest_rms.filter(variable="*CO2").line_plot(ax=ax, **pkwargs)
# sr15_data_closest_rms.filter(variable="*CO2", **example_model_scen).line_plot(ax=ax, color="black")
filler_input.filter(variable="*CO2").line_plot(ax=ax, color="black", linestyle="--", dashes=(10, 15))
ax.set_title("Database CO$_2$ and lead emissions timeseries")

ax = fig.add_subplot(122)
sr15_data_closest_rms.filter(variable="*VOC").line_plot(ax=ax, **pkwargs)
filler_input_filled.filter(variable="*VOC").line_plot(ax=ax, color="black", linestyle="--", dashes=(10, 15))
ax.set_title("Database VOC and filled follower emissions timeseries")

plt.tight_layout()

# %% [markdown]
# As we can see, on an RMS basis our input timeseries is closest to the 'ADVANCE_2030_Med2C' scenario and hence its `Emissions|VOC` pathway is returned.

# %%
#NBVAL_IGNORE_OUTPUT
filler_input_filled.timeseries()
# Out:
#                                                                                2005  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|VOC Mt VOC/yr  189.212
#
#                                                                                   2010  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|VOC Mt VOC/yr  164.056724
#
#                                                                                   2015  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|VOC Mt VOC/yr  153.575866
#
#                                                                                   2020  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|VOC Mt VOC/yr  145.611005
#
#                                                                                   2025  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|VOC Mt VOC/yr  130.387433
#
#                                                                                   2030  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|VOC Mt VOC/yr  115.465871
#
#                                                                                  2035  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|VOC Mt VOC/yr  95.506957
#
#                                                                                  2040  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|VOC Mt VOC/yr  80.043895
#
#                                                                                 2045  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|VOC Mt VOC/yr  68.04429
#
#                                                                                  2050  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|VOC Mt VOC/yr  56.038428
#
#                                                                                  2055  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|VOC Mt VOC/yr  52.164286
#
#                                                                                  2060  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|VOC Mt VOC/yr  50.849028
#
#                                                                                  2065  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|VOC Mt VOC/yr  49.479184
#
#                                                                                  2070  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|VOC Mt VOC/yr  48.134296
#
#                                                                                  2075  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|VOC Mt VOC/yr  47.046133
#
#                                                                                  2080  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|VOC Mt VOC/yr  45.615107
#
#                                                                                  2085  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|VOC Mt VOC/yr  43.948576
#
#                                                                                  2090  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|VOC Mt VOC/yr  42.192038
#
#                                                                                  2095  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|VOC Mt VOC/yr  40.390822
#
#                                                                                  2100
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|VOC Mt VOC/yr  38.480263

# %%
#NBVAL_IGNORE_OUTPUT
sr15_data_closest_rms.filter(scenario="ADVANCE_2030_Med2C", variable="Emissions|VOC").timeseries()
# Out:
#                                                                         2005  \
# model             scenario           region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_2030_Med2C World  Emissions|VOC Mt VOC/yr  189.212
#
#                                                                            2010  \
# model             scenario           region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_2030_Med2C World  Emissions|VOC Mt VOC/yr  164.056724
#
#                                                                            2015  \
# model             scenario           region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_2030_Med2C World  Emissions|VOC Mt VOC/yr  153.575866
#
#                                                                            2020  \
# model             scenario           region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_2030_Med2C World  Emissions|VOC Mt VOC/yr  145.611005
#
#                                                                            2025  \
# model             scenario           region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_2030_Med2C World  Emissions|VOC Mt VOC/yr  130.387433
#
#                                                                            2030  \
# model             scenario           region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_2030_Med2C World  Emissions|VOC Mt VOC/yr  115.465871
#
#                                                                           2035  \
# model             scenario           region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_2030_Med2C World  Emissions|VOC Mt VOC/yr  95.506957
#
#                                                                           2040  \
# model             scenario           region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_2030_Med2C World  Emissions|VOC Mt VOC/yr  80.043895
#
#                                                                          2045  \
# model             scenario           region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_2030_Med2C World  Emissions|VOC Mt VOC/yr  68.04429
#
#                                                                           2050  \
# model             scenario           region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_2030_Med2C World  Emissions|VOC Mt VOC/yr  56.038428
#
#                                                                           2055  \
# model             scenario           region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_2030_Med2C World  Emissions|VOC Mt VOC/yr  52.164286
#
#                                                                           2060  \
# model             scenario           region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_2030_Med2C World  Emissions|VOC Mt VOC/yr  50.849028
#
#                                                                           2065  \
# model             scenario           region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_2030_Med2C World  Emissions|VOC Mt VOC/yr  49.479184
#
#                                                                           2070  \
# model             scenario           region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_2030_Med2C World  Emissions|VOC Mt VOC/yr  48.134296
#
#                                                                           2075  \
# model             scenario           region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_2030_Med2C World  Emissions|VOC Mt VOC/yr  47.046133
#
#                                                                           2080  \
# model             scenario           region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_2030_Med2C World  Emissions|VOC Mt VOC/yr  45.615107
#
#                                                                           2085  \
# model             scenario           region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_2030_Med2C World  Emissions|VOC Mt VOC/yr  43.948576
#
#                                                                           2090  \
# model             scenario           region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_2030_Med2C World  Emissions|VOC Mt VOC/yr  42.192038
#
#                                                                           2095  \
# model             scenario           region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_2030_Med2C World  Emissions|VOC Mt VOC/yr  40.390822
#
#                                                                           2100
# model             scenario           region variable      unit
# WITCH-GLOBIOM 4.2 ADVANCE_2030_Med2C World  Emissions|VOC Mt VOC/yr  38.480263

# %% [markdown]
# ### Rolling Window Quantile cruncher
#
# This cruncher uses the 'rolling window quantile' methodology. It is described by its docstring.

# %%
print(silicone.database_crunchers.DatabaseCruncherQuantileRollingWindows.__doc__)
# silicone.database_crunchers.DatabaseCruncherQuantileRollingWindows?
# Out:
#     Database cruncher which uses the 'rolling windows' technique.
#
#     This cruncher derives the relationship between two variables by performing
#     quantile calculations between the follower timeseries and the lead timeseries.
#     These calculations are performed at each timestep in the timeseries, independent
#     of the other timesteps.
#
#     For each timestep, the lead timeseries axis is divided into multiple evenly spaced
#     windows (to date this is only tested on 1:1 relationships but may work with more
#     than one lead timeseries). In each window, every data point in the database is
#     included. However, the data points receive a weight given by
#
#     .. math::
#
#         w(x, x_{\text{window}}) = \frac{1}{1 + (d_n)^2}
#
#     where :math:`w` is the weight and :math:`d_n` is the normalised distance between
#     the centre of the window and the data point's position on the lead timeseries axis.
#
#     :math:`d_n` is calculated as
#
#     .. math::
#
#         d_n = \frac{x - x_{\text{window}}}{f \times (\frac{b}{2})}
#
#     where :math:`x` is the position of the data point on the lead timeseries axis,
#     :math:`x_{\text{window}}` is the position of the centre of the window on the lead
#     timeseries axis, :math:`b` is the distance between window centres and :math:`f` is
#     a decay factor which controls how much less points away from :math:`x_{\
#     text{window}}` are weighted. If :math:`f=1` then a point which is halfway between
#     window centres receives a weighting of :math:`1/2`. Lowering the value of
#     :math:`f` cause points further from the window centre to receive less weight.
#
#     With these weightings, the desired quantile of the data is then calculated. This
#     calculation is done by sorting the data, and then choosing the first data point
#     from the database which sits above or equal to the given quantile, with each data
#     point's contribution to the quantile calculation being weighted by its weight. As
#     a result, this cruncher limits itself to using data within the distribution and
#     will not make any assumptions about the shape of the distribution.
#
#     By varying the quantile, this cruncher can provide ranges of the relationship
#     between different variables. For example, it can provide the 90th percentile (i.e.
#     high end) of the relationship between e.g. ``Emissions|CH4`` and ``Emissions|CO2``
#     or the 50th percentile (i.e. median) or any other arbitrary percentile/quantile
#     choice.

# %% [markdown]
# #### Infilling
#
# Because it relies on quantile analysis, this database does best with large amounts of data. Hence we keep quite a lot of emissions timeseries before beginning.

# %%
sr15_data_quantile = sr15_data.copy().filter(
    model=["WITCH-GLOBIOM 4.2"], variable=["Emissions|CO2", "Emissions|VOC"]
)

# %%
cruncher = silicone.database_crunchers.DatabaseCruncherQuantileRollingWindows(sr15_data_quantile)

# %%
filler = cruncher.derive_relationship("Emissions|VOC", ["Emissions|CO2"])
print(filler.__doc__)
# filler?
# Out:
#             Filler function derived from :obj:`DatabaseCruncherQuantileRollingWindows`.
#
#             Parameters
#             ----------
#             in_iamdf : :obj:`pyam.IamDataFrame`
#                 Input data to fill data in
#
#             Returns
#             -------
#             :obj:`pyam.IamDataFrame`
#                 Filled in data (without original source data)
#
#             Raises
#             ------
#             ValueError
#                 The key db_times for filling are not in ``in_iamdf``.

# %% [markdown]
# Now we can infill.

# %%
filler_data = sr15_data.filter(
    model="MESSAGEix-GLOBIOM 1.0", 
    scenario="CD-LINKS_NPi2020_1600", 
    variable=["Emissions|CO2"]
)

# %% [markdown]
# The `filler_data` is missing `Emissions|VOC`.

# %%
#NBVAL_IGNORE_OUTPUT
filler_data.filter(variable="Emissions|VOC").data
# Out:
# WARNING:root:Filtered IamDataFrame is empty!
# Empty DataFrame
# Columns: [model, scenario, region, variable, unit, year, value]
# Index: []

# %% [markdown]
# The rolling windows quantile can only downscale on the timesteps in the database. If this isn't the case, we will receive a `ValueError`.

# %%
try:
    filler(filler_data)
except ValueError:
    traceback.print_exc(limit=0, chain=False)
# Out:
# Traceback (most recent call last):
# ValueError: Not all required timepoints are present in the database we crunched, we crunched
# 	`[2005, 2010, 2015, 2020, 2025, 2030, 2035, 2040, 2045, 2050, 2055, 2060, 2065, 2070, 2075, 2080, 2085, 2090, 2095, 2100]`
# but you passed in
# 	[2000, 2005, 2010, 2020, 2030, 2040, 2050, 2060, 2070, 2080, 2090, 2100]

# %% [markdown]
# We can fix this by filtering first.

# %%
# NBVAL_IGNORE_OUTPUT
filler_data = filler_data.filter(year=sr15_data_quantile["year"].unique())

# %%
#NBVAL_IGNORE_OUTPUT
filler_data.timeseries()
# Out:
#                                                                                   2005  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|CO2 Mt CO2/yr  35933.0697
#
#                                                                                    2010  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|CO2 Mt CO2/yr  38542.01816
#
#                                                                                    2020  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|CO2 Mt CO2/yr  39615.22255
#
#                                                                                    2030  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|CO2 Mt CO2/yr  37981.07524
#
#                                                                                    2040  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|CO2 Mt CO2/yr  33271.92656
#
#                                                                                    2050  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|CO2 Mt CO2/yr  25181.95619
#
#                                                                                    2060  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|CO2 Mt CO2/yr  13847.19271
#
#                                                                                    2070  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|CO2 Mt CO2/yr  5163.226383
#
#                                                                                    2080  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|CO2 Mt CO2/yr -2068.503671
#
#                                                                                    2090  \
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|CO2 Mt CO2/yr -7525.726077
#
#                                                                                    2100
# model                 scenario              region variable      unit
# MESSAGEix-GLOBIOM 1.0 CD-LINKS_NPi2020_1600 World  Emissions|CO2 Mt CO2/yr -10662.64286

# %%
#NBVAL_IGNORE_OUTPUT
filler_data_filled = filler(filler_data)
filler_data_filled.head()
# Out:
#                    model               scenario region       variable  \
# 0  MESSAGEix-GLOBIOM 1.0  CD-LINKS_NPi2020_1600  World  Emissions|VOC
# 1  MESSAGEix-GLOBIOM 1.0  CD-LINKS_NPi2020_1600  World  Emissions|VOC
# 2  MESSAGEix-GLOBIOM 1.0  CD-LINKS_NPi2020_1600  World  Emissions|VOC
# 3  MESSAGEix-GLOBIOM 1.0  CD-LINKS_NPi2020_1600  World  Emissions|VOC
# 4  MESSAGEix-GLOBIOM 1.0  CD-LINKS_NPi2020_1600  World  Emissions|VOC
#
#         unit  year       value
# 0  Mt VOC/yr  2005  189.212000
# 1  Mt VOC/yr  2010  164.056724
# 2  Mt VOC/yr  2020  145.611005
# 3  Mt VOC/yr  2030  115.465871
# 4  Mt VOC/yr  2040   89.302542

# %%
pkwargs = {"color": "scenario", "linewidth": 2}

fig = plt.figure(figsize=(16, 9))
ax = fig.add_subplot(121)
sr15_data_quantile.filter(variable="*CO2").line_plot(ax=ax, **pkwargs)
# sr15_data_closest_rms.filter(variable="*CO2", **example_model_scen).line_plot(ax=ax, color="black")
filler_data.filter(variable="*CO2").line_plot(ax=ax, color="black", linestyle="--", dashes=(10, 15))
ax.set_title("Database CO$_2$ and lead emissions timeseries")

ax = fig.add_subplot(122)
sr15_data_quantile.filter(variable="*VOC").line_plot(ax=ax, **pkwargs)
filler_data_filled.filter(variable="*VOC").line_plot(ax=ax, color="black", linestyle="--", dashes=(10, 15))
ax.set_title("Database VOC and filled follower emissions timeseries")

plt.tight_layout()

# %% [markdown]
# #### Recovering the data you put in

# %% [markdown]
# Because of the averaging mechanism, the cruncher will only precisely reproduce the input data when only one timeseries is put into it. With multiple data series, this is not guaranteed, although will happen in the limit case of many windows.
#
# This section does not illustrate new functionality, merely investigates the mathematical effects of changing the number of windows.

# %%
# NBVAL_IGNORE_OUTPUT
# Multiple data are input - the 50th percentile and nwindows=10 is the default
filler_data = sr15_data_quantile.filter(scenario='ADVANCE_2030_Med2C')
self_cruncher = silicone.database_crunchers.DatabaseCruncherQuantileRollingWindows(sr15_data)
self_filler_default = self_cruncher.derive_relationship("Emissions|VOC", ["Emissions|VOC"], nwindows=10)
infilled_quantile = self_filler_default(filler_data)
infilled_quantile.head()
# Out:
#                model            scenario region       variable       unit  \
# 0  WITCH-GLOBIOM 4.2  ADVANCE_2030_Med2C  World  Emissions|VOC  Mt VOC/yr
# 1  WITCH-GLOBIOM 4.2  ADVANCE_2030_Med2C  World  Emissions|VOC  Mt VOC/yr
# 2  WITCH-GLOBIOM 4.2  ADVANCE_2030_Med2C  World  Emissions|VOC  Mt VOC/yr
# 3  WITCH-GLOBIOM 4.2  ADVANCE_2030_Med2C  World  Emissions|VOC  Mt VOC/yr
# 4  WITCH-GLOBIOM 4.2  ADVANCE_2030_Med2C  World  Emissions|VOC  Mt VOC/yr
#
#    year       value
# 0  2005  192.070847
# 1  2010  161.751368
# 2  2015  153.277468
# 3  2020  145.844938
# 4  2025  127.431849

# %% [markdown]
# The default behaviour shows the correct trend, but the windows-based interpolation introduces some noise.

# %%
# NBVAL_IGNORE_OUTPUT
pkwargs = {"color": "scenario", "linewidth": 2}
fig = plt.figure(figsize=(6, 6))
ax = fig.add_subplot()
filler_data.filter(variable='Emissions|VOC', ).line_plot(ax=ax, **pkwargs)
infilled_quantile.filter(variable='Emissions|VOC').line_plot(ax=ax, color="black", linestyle="--", dashes=(8, 10))

# %% [markdown]
# By increasing the windows number, we can get a higher fidelity - at the cost of more computational power and less averaging over different datapoints.

# %%
# NBVAL_IGNORE_OUTPUT
# With a lower window number, the deviations become clearer
self_filler_low_w = self_cruncher.derive_relationship("Emissions|VOC", ["Emissions|VOC"], nwindows=2)
infilled_low_w = self_filler_low_w(filler_data)
infilled_low_w.head()
# Out:
#                model            scenario region       variable       unit  \
# 0  WITCH-GLOBIOM 4.2  ADVANCE_2030_Med2C  World  Emissions|VOC  Mt VOC/yr
# 1  WITCH-GLOBIOM 4.2  ADVANCE_2030_Med2C  World  Emissions|VOC  Mt VOC/yr
# 2  WITCH-GLOBIOM 4.2  ADVANCE_2030_Med2C  World  Emissions|VOC  Mt VOC/yr
# 3  WITCH-GLOBIOM 4.2  ADVANCE_2030_Med2C  World  Emissions|VOC  Mt VOC/yr
# 4  WITCH-GLOBIOM 4.2  ADVANCE_2030_Med2C  World  Emissions|VOC  Mt VOC/yr
#
#    year       value
# 0  2005  183.151752
# 1  2010  173.061130
# 2  2015  162.837011
# 3  2020  160.773780
# 4  2025  146.316428

# %%
# NBVAL_IGNORE_OUTPUT
# Higher window numbers mean that we weight data with the exact same x-value more highly, recovering the original relation
self_filler_high_w = self_cruncher.derive_relationship("Emissions|VOC", ["Emissions|VOC"], nwindows=30)
infilled_high_w = self_filler_high_w(filler_data)
infilled_high_w.head()
# Out:
#                model            scenario region       variable       unit  \
# 0  WITCH-GLOBIOM 4.2  ADVANCE_2030_Med2C  World  Emissions|VOC  Mt VOC/yr
# 1  WITCH-GLOBIOM 4.2  ADVANCE_2030_Med2C  World  Emissions|VOC  Mt VOC/yr
# 2  WITCH-GLOBIOM 4.2  ADVANCE_2030_Med2C  World  Emissions|VOC  Mt VOC/yr
# 3  WITCH-GLOBIOM 4.2  ADVANCE_2030_Med2C  World  Emissions|VOC  Mt VOC/yr
# 4  WITCH-GLOBIOM 4.2  ADVANCE_2030_Med2C  World  Emissions|VOC  Mt VOC/yr
#
#    year       value
# 0  2005  190.326512
# 1  2010  164.168245
# 2  2015  153.575866
# 3  2020  144.936194
# 4  2025  129.585687

# %%
# NBVAL_IGNORE_OUTPUT
# Here the lower window count (orange) results in large deviations whereas the high window case (red) provides a close match. 
pkwargs = {"color": "scenario", "linewidth": 2}
fig = plt.figure(figsize=(16, 9))
ax = fig.add_subplot(121)
# This line illustrates the background data informing the deviations (but confuses the plots). 
# Re-add it in place of the legend line if desired
#sr15_data.filter(variable='Emissions|VOC',).line_plot(ax=ax, linewidth=0.1)

filler_data.filter(variable='Emissions|VOC', ).line_plot(ax=ax, **pkwargs)
infilled_quantile.filter(variable='Emissions|VOC').line_plot(ax=ax, color="black", linestyle="--", dashes=(8, 10))
infilled_low_w.line_plot(ax=ax, color="blue", linestyle="--", dashes=(7, 8))
infilled_high_w.line_plot(ax=ax, color="red", linestyle="--", dashes=(7, 8))
plt.legend(['Original', 'n=10', 'n=2', 'n=30'])

# %% [markdown]
# ### Time-dependent ratio cruncher
# This cruncher uses the 'time-dependent ratio' methodology. It is described by its docstring.

# %%
print(silicone.database_crunchers.DatabaseCruncherTimeDepRatio.__doc__)
# Out:
#     Database cruncher which uses the 'time-dependent ratio' technique.
#
#     This cruncher derives the relationship between two variables by simply assuming
#     that the follower timeseries is equal to the lead timeseries multiplied by a
#     time-dependent scaling factor. The scaling factor is the ratio of the
#     follower variable to the lead variable. If the database contains many such pairs,
#     the scaling factor is the ratio between the means of the values.
#
#     Once the relationship is derived, the 'filler' function will infill following:
#
#     .. math::
#         E_f(t) = s(t) * E_l(t)
#
#     where :math:`E_f(t)` is emissions of the follower variable and :math:`E_l(t)` is
#     emissions of the lead variable.
#
#     :math:`s(t)` is the scaling factor, calculated as the ratio of the means of the
#     the follower and the leader in the cruncher in the database.
#
#     .. math::
#         s(t) = \frac{mean( E_f(t) )}{mean( E_l(t) )})

# %% [markdown]
# #### Infilling
# This technique is extracts only a single constant multiplier from all data fed in to the cruncher, so additional data does not radically change how it behaves. We will use the same amount of data as in the previous case for comparison. This cruncher works well for cases like splitting groups of gases into constituent parts, but poorly for gases which may have negative emissions.

# %%
sr15_data_tdr = sr15_data.copy().filter(
    model=["WITCH-GLOBIOM 4.2"], 
    variable=["Emissions|CO2", "Emissions|VOC", "Emissions|CH4" ,"Emissions|HCF*"]
)

# %%
cruncher = silicone.database_crunchers.DatabaseCruncherTimeDepRatio(sr15_data_tdr)
filler = cruncher.derive_relationship("Emissions|VOC", ["Emissions|CO2"])
print(filler.__doc__)
# Out:
#             Filler function derived from :obj:`DatabaseCruncherTimeDepRatio`.
#
#             Parameters
#             ----------
#             in_iamdf : :obj:`pyam.IamDataFrame`
#                 Input data to fill data in
#
#             Returns
#             -------
#             :obj:`pyam.IamDataFrame`
#                 Filled-in data (without original source data)
#
#             Raises
#             ------
#             ValueError
#                 The key year for filling is not in ``in_iamdf``.

# %%
# NBVAL_IGNORE_OUTPUT
filler_data = sr15_data.filter(
    model="MESSAGEix-GLOBIOM 1.0", 
    scenario="CD-LINKS_NPi2020_1600", 
    variable=["Emissions|CO2"]
)
filler_data = filler_data.filter(year=sr15_data_quantile["year"].unique())
filler_data.data
# Out:
#                         model               scenario region       variable  \
# 148226  MESSAGEix-GLOBIOM 1.0  CD-LINKS_NPi2020_1600  World  Emissions|CO2
# 148227  MESSAGEix-GLOBIOM 1.0  CD-LINKS_NPi2020_1600  World  Emissions|CO2
# 148228  MESSAGEix-GLOBIOM 1.0  CD-LINKS_NPi2020_1600  World  Emissions|CO2
# 148229  MESSAGEix-GLOBIOM 1.0  CD-LINKS_NPi2020_1600  World  Emissions|CO2
# 148230  MESSAGEix-GLOBIOM 1.0  CD-LINKS_NPi2020_1600  World  Emissions|CO2
# 148231  MESSAGEix-GLOBIOM 1.0  CD-LINKS_NPi2020_1600  World  Emissions|CO2
# 148232  MESSAGEix-GLOBIOM 1.0  CD-LINKS_NPi2020_1600  World  Emissions|CO2
# 148233  MESSAGEix-GLOBIOM 1.0  CD-LINKS_NPi2020_1600  World  Emissions|CO2
# 148234  MESSAGEix-GLOBIOM 1.0  CD-LINKS_NPi2020_1600  World  Emissions|CO2
# 148235  MESSAGEix-GLOBIOM 1.0  CD-LINKS_NPi2020_1600  World  Emissions|CO2
# 148236  MESSAGEix-GLOBIOM 1.0  CD-LINKS_NPi2020_1600  World  Emissions|CO2
#
#              unit  year         value
# 148226  Mt CO2/yr  2005  35933.069700
# 148227  Mt CO2/yr  2010  38542.018160
# 148228  Mt CO2/yr  2020  39615.222550
# 148229  Mt CO2/yr  2030  37981.075240
# 148230  Mt CO2/yr  2040  33271.926560
# 148231  Mt CO2/yr  2050  25181.956190
# 148232  Mt CO2/yr  2060  13847.192710
# 148233  Mt CO2/yr  2070   5163.226383
# 148234  Mt CO2/yr  2080  -2068.503671
# 148235  Mt CO2/yr  2090  -7525.726077
# 148236  Mt CO2/yr  2100 -10662.642860

# %%
# NBVAL_IGNORE_OUTPUT
results= filler(filler_data)
results.head()
# Out:
#                    model               scenario region       variable  \
# 0  MESSAGEix-GLOBIOM 1.0  CD-LINKS_NPi2020_1600  World  Emissions|VOC
# 1  MESSAGEix-GLOBIOM 1.0  CD-LINKS_NPi2020_1600  World  Emissions|VOC
# 2  MESSAGEix-GLOBIOM 1.0  CD-LINKS_NPi2020_1600  World  Emissions|VOC
# 3  MESSAGEix-GLOBIOM 1.0  CD-LINKS_NPi2020_1600  World  Emissions|VOC
# 4  MESSAGEix-GLOBIOM 1.0  CD-LINKS_NPi2020_1600  World  Emissions|VOC
#
#         unit  year       value
# 0  Mt VOC/yr  2005  214.182356
# 1  Mt VOC/yr  2010  185.661118
# 2  Mt VOC/yr  2020  152.067950
# 3  Mt VOC/yr  2030  125.620801
# 4  Mt VOC/yr  2040   99.084653

# %% [markdown]
# We observe that the results become anomalous when the lead emissions may be negative:

# %%
pkwargs = {"color": "scenario", "linewidth": 2}

fig = plt.figure(figsize=(16, 9))
ax = fig.add_subplot(121)
sr15_data_tdr.filter(variable="*CO2").line_plot(ax=ax, **pkwargs)
filler_data.filter(variable="*CO2").line_plot(ax=ax, color="black", linestyle="--", dashes=(10, 15))
ax.set_title("Database CO$_2$ and lead emissions timeseries")

ax = fig.add_subplot(122)
sr15_data_tdr.filter(variable="*VOC").line_plot(ax=ax, **pkwargs)
results.filter(variable="*VOC").line_plot(ax=ax, color="black", linestyle="--", dashes=(10, 15))
ax.set_title("Database VOC and filled follower emissions timeseries")

plt.tight_layout()

# %% [markdown]
# #### HFC emission splitting
# One of the features of the time-dependent ratio is that if the constituent elements consistently add up to a particular value, the infilled results will too, i.e. if for gases A, B, C we have A = B + C in all source material, then this will hold for the infilled values too. This makes it particularly appropriate for splitting gases into their constituents.

# %%
sr15_data_hfc = sr15_data.filter(variable="Emissions|HFC*")
sr15_data_hfc.variables()
# Out:
# 0             Emissions|HFC
# 1      Emissions|HFC|HFC125
# 2     Emissions|HFC|HFC134a
# 3     Emissions|HFC|HFC143a
# 4    Emissions|HFC|HFC227ea
# 5       Emissions|HFC|HFC23
# 6       Emissions|HFC|HFC32
# 7    Emissions|HFC|HFC43-10
# 8    Emissions|HFC|HFC245fa
# Name: variable, dtype: object

# %%
# We don't have all variables for all scenarios, but by finding a scenario where we do we can make progress
common_models = set(sr15_data_hfc.filter(variable="Emissions|HFC|HFC245fa").models()).intersection(
    set(sr15_data_hfc.filter(variable="Emissions|HFC").models())
)
common_scenarios = set(sr15_data_hfc.filter(variable="Emissions|HFC|HFC245fa", model=common_models).scenarios()).intersection(
    set(sr15_data_hfc.filter(variable="Emissions|HFC", model=common_models).scenarios())
)
infill_scenarios = "GEA_Eff_1p5C"
#set(sr15_data_hfc.filter(variable="Emissions|HFC").scenarios()) - set(sr15_data_hfc.filter(variable="Emissions|HFC|HFC245fa").scenarios())

infill_models ='MESSAGE V.3' 
# set(sr15_data_hfc.filter(variable="Emissions|HFC").models()) - set(sr15_data_hfc.filter(variable="Emissions|HFC|HFC245fa").models())

infill_scenarios
# Out:
# 'GEA_Eff_1p5C'

# %%
common_years = np.arange(2010, 2105, 10)
hfc_training_data = sr15_data_hfc.filter(model=common_models, scenario=common_scenarios, year=common_years)
cruncher = silicone.database_crunchers.DatabaseCruncherTimeDepRatio(hfc_training_data)
filler = cruncher.derive_relationship("Emissions|HFC|HFC245fa", ["Emissions|HFC"])

# %%
#NBVAL_IGNORE_OUTPUT
to_infill = sr15_data_hfc.filter(model=infill_models, scenario=infill_scenarios, year=common_years)
infilled = filler(to_infill)
infilled.head()
# Out:
#          model      scenario region                variable            unit  \
# 0  MESSAGE V.3  GEA_Eff_1p5C  World  Emissions|HFC|HFC245fa  kt HFC245fa/yr
# 1  MESSAGE V.3  GEA_Eff_1p5C  World  Emissions|HFC|HFC245fa  kt HFC245fa/yr
# 2  MESSAGE V.3  GEA_Eff_1p5C  World  Emissions|HFC|HFC245fa  kt HFC245fa/yr
# 3  MESSAGE V.3  GEA_Eff_1p5C  World  Emissions|HFC|HFC245fa  kt HFC245fa/yr
# 4  MESSAGE V.3  GEA_Eff_1p5C  World  Emissions|HFC|HFC245fa  kt HFC245fa/yr
#
#    year      value
# 0  2010   8.353984
# 1  2020  10.940379
# 2  2030   7.903901
# 3  2040  10.049366
# 4  2050  11.305758

# %%
# NBVAL_IGNORE_OUTPUT
pkwargs = {"color": "scenario", "linewidth": 2}

fig = plt.figure(figsize=(16, 9))
ax = fig.add_subplot(121)
hfc_training_data.filter(variable="*HFC").line_plot(ax=ax, **pkwargs)
to_infill.filter(variable="*HFC").line_plot(ax=ax, color="black", linestyle="--", dashes=(10, 15))
ax.set_title("Database HFC and lead emissions timeseries")

ax = fig.add_subplot(122)
hfc_training_data.filter(variable="*HFC245fa").line_plot(ax=ax, **pkwargs)
infilled.filter(variable="*HFC245fa").line_plot(ax=ax, color="black", linestyle="--", dashes=(10, 15))
ax.set_title("Database HFC245fa and filled follower emissions timeseries")

plt.tight_layout()
# Out:
# INFO:root:>=13 labels, not applying legend
# INFO:root:>=13 labels, not applying legend
# INFO:root:>=13 labels, not applying legend
# INFO:root:>=13 labels, not applying legend

# %% [markdown]
# ### Constant ratio cruncher
# This infiller simply multiples a known value by a constant, which it must be told. It must also be told the units of the value it returns. It does not require an input dataframe.

# %%
print(silicone.database_crunchers.DatabaseCruncherTimeDepRatio.__doc__)
# Out:
#     Database cruncher which uses the 'time-dependent ratio' technique.
#
#     This cruncher derives the relationship between two variables by simply assuming
#     that the follower timeseries is equal to the lead timeseries multiplied by a
#     time-dependent scaling factor. The scaling factor is the ratio of the
#     follower variable to the lead variable. If the database contains many such pairs,
#     the scaling factor is the ratio between the means of the values.
#
#     Once the relationship is derived, the 'filler' function will infill following:
#
#     .. math::
#         E_f(t) = s(t) * E_l(t)
#
#     where :math:`E_f(t)` is emissions of the follower variable and :math:`E_l(t)` is
#     emissions of the lead variable.
#
#     :math:`s(t)` is the scaling factor, calculated as the ratio of the means of the
#     the follower and the leader in the cruncher in the database.
#
#     .. math::
#         s(t) = \frac{mean( E_f(t) )}{mean( E_l(t) )})

# %%
cruncher = silicone.database_crunchers.DatabaseCruncherConstantRatio()
filler = cruncher.derive_relationship("Emissions|VOC", ["Emissions|CO2"], 0.5, "kt VOC/yr")
print(filler.__doc__)
# Out:
#             Filler function derived from :obj:`DatabaseCruncherTimeDepRatio`.
#
#             Parameters
#             ----------
#             in_iamdf : :obj:`pyam.IamDataFrame`
#                 Input data to fill data in
#
#             Returns
#             -------
#             :obj:`pyam.IamDataFrame`
#                 Filled-in data (without original source data)
#
#             Raises
#             ------
#             ValueError
#                 The key year for filling is not in ``in_iamdf``.

# %%
#NBVAL_IGNORE_OUTPUT
to_infill = sr15_data.filter(model=infill_models)
infilled = filler(to_infill)
infilled.head()
# Out:
#          model      scenario region       variable       unit  year  \
# 0  MESSAGE V.3  GEA_Eff_1p5C  World  Emissions|VOC  kt VOC/yr  2005
# 1  MESSAGE V.3  GEA_Eff_1p5C  World  Emissions|VOC  kt VOC/yr  2010
# 2  MESSAGE V.3  GEA_Eff_1p5C  World  Emissions|VOC  kt VOC/yr  2020
# 3  MESSAGE V.3  GEA_Eff_1p5C  World  Emissions|VOC  kt VOC/yr  2030
# 4  MESSAGE V.3  GEA_Eff_1p5C  World  Emissions|VOC  kt VOC/yr  2040
#
#           value
# 0  17295.289000
# 1  18153.620835
# 2  13441.906500
# 3   8486.221335
# 4   4666.918666

# %% [markdown]
# The values returned are simply the input, scaled by a factor.

# %%
infilled.timeseries()
# Out:
#                                                                                            2005  \
# model       scenario                               region variable      unit
# MESSAGE V.3 GEA_Eff_1p5C                           World  Emissions|VOC kt VOC/yr  17295.289000
#             GEA_Eff_1p5C_Delay2020                 World  Emissions|VOC kt VOC/yr  17223.972335
#             GEA_Eff_2C_Delay2020                   World  Emissions|VOC kt VOC/yr  17224.615835
#             GEA_Eff_AdvNCO2_1p5C                   World  Emissions|VOC kt VOC/yr  17295.787665
#             GEA_Eff_base                           World  Emissions|VOC kt VOC/yr  17295.967335
#             GEA_Mix_1p5C_AdvNCO2_PartialDelay2020  World  Emissions|VOC kt VOC/yr  16952.252165
#             GEA_Mix_1p5C_AdvTrans_PartialDelay2020 World  Emissions|VOC kt VOC/yr  17235.496665
#             GEA_Mix_2C_AdvNCO2_PartialDelay2020    World  Emissions|VOC kt VOC/yr  17236.209835
#             GEA_Mix_2C_AdvTrans_PartialDelay2020   World  Emissions|VOC kt VOC/yr  17236.208000
#             GEA_Mix_base                           World  Emissions|VOC kt VOC/yr  17293.488665
#
#                                                                                            2010  \
# model       scenario                               region variable      unit
# MESSAGE V.3 GEA_Eff_1p5C                           World  Emissions|VOC kt VOC/yr  18153.620835
#             GEA_Eff_1p5C_Delay2020                 World  Emissions|VOC kt VOC/yr  18177.331335
#             GEA_Eff_2C_Delay2020                   World  Emissions|VOC kt VOC/yr  18177.982165
#             GEA_Eff_AdvNCO2_1p5C                   World  Emissions|VOC kt VOC/yr  18153.870165
#             GEA_Eff_base                           World  Emissions|VOC kt VOC/yr  18154.634665
#             GEA_Mix_1p5C_AdvNCO2_PartialDelay2020  World  Emissions|VOC kt VOC/yr  17897.058665
#             GEA_Mix_1p5C_AdvTrans_PartialDelay2020 World  Emissions|VOC kt VOC/yr  18210.360665
#             GEA_Mix_2C_AdvNCO2_PartialDelay2020    World  Emissions|VOC kt VOC/yr  18210.879500
#             GEA_Mix_2C_AdvTrans_PartialDelay2020   World  Emissions|VOC kt VOC/yr  18210.897835
#             GEA_Mix_base                           World  Emissions|VOC kt VOC/yr  18173.338335
#
#                                                                                            2020  \
# model       scenario                               region variable      unit
# MESSAGE V.3 GEA_Eff_1p5C                           World  Emissions|VOC kt VOC/yr  13441.906500
#             GEA_Eff_1p5C_Delay2020                 World  Emissions|VOC kt VOC/yr  19383.459335
#             GEA_Eff_2C_Delay2020                   World  Emissions|VOC kt VOC/yr  19384.469500
#             GEA_Eff_AdvNCO2_1p5C                   World  Emissions|VOC kt VOC/yr  15442.161165
#             GEA_Eff_base                           World  Emissions|VOC kt VOC/yr  19371.768165
#             GEA_Mix_1p5C_AdvNCO2_PartialDelay2020  World  Emissions|VOC kt VOC/yr  17212.899000
#             GEA_Mix_1p5C_AdvTrans_PartialDelay2020 World  Emissions|VOC kt VOC/yr  17576.346335
#             GEA_Mix_2C_AdvNCO2_PartialDelay2020    World  Emissions|VOC kt VOC/yr  17578.909335
#             GEA_Mix_2C_AdvTrans_PartialDelay2020   World  Emissions|VOC kt VOC/yr  17577.281335
#             GEA_Mix_base                           World  Emissions|VOC kt VOC/yr  21864.388335
#
#                                                                                            2030  \
# model       scenario                               region variable      unit
# MESSAGE V.3 GEA_Eff_1p5C                           World  Emissions|VOC kt VOC/yr   8486.221335
#             GEA_Eff_1p5C_Delay2020                 World  Emissions|VOC kt VOC/yr  12156.292500
#             GEA_Eff_2C_Delay2020                   World  Emissions|VOC kt VOC/yr  16759.660500
#             GEA_Eff_AdvNCO2_1p5C                   World  Emissions|VOC kt VOC/yr  11393.050165
#             GEA_Eff_base                           World  Emissions|VOC kt VOC/yr  20057.629165
#             GEA_Mix_1p5C_AdvNCO2_PartialDelay2020  World  Emissions|VOC kt VOC/yr  12118.384665
#             GEA_Mix_1p5C_AdvTrans_PartialDelay2020 World  Emissions|VOC kt VOC/yr  12629.393335
#             GEA_Mix_2C_AdvNCO2_PartialDelay2020    World  Emissions|VOC kt VOC/yr  16215.981835
#             GEA_Mix_2C_AdvTrans_PartialDelay2020   World  Emissions|VOC kt VOC/yr  16725.085665
#             GEA_Mix_base                           World  Emissions|VOC kt VOC/yr  24939.627165
#
#                                                                                            2040  \
# model       scenario                               region variable      unit
# MESSAGE V.3 GEA_Eff_1p5C                           World  Emissions|VOC kt VOC/yr   4666.918666
#             GEA_Eff_1p5C_Delay2020                 World  Emissions|VOC kt VOC/yr   6347.867165
#             GEA_Eff_2C_Delay2020                   World  Emissions|VOC kt VOC/yr  12387.384165
#             GEA_Eff_AdvNCO2_1p5C                   World  Emissions|VOC kt VOC/yr   6972.480165
#             GEA_Eff_base                           World  Emissions|VOC kt VOC/yr  21455.820835
#             GEA_Mix_1p5C_AdvNCO2_PartialDelay2020  World  Emissions|VOC kt VOC/yr   6141.100165
#             GEA_Mix_1p5C_AdvTrans_PartialDelay2020 World  Emissions|VOC kt VOC/yr   6855.709665
#             GEA_Mix_2C_AdvNCO2_PartialDelay2020    World  Emissions|VOC kt VOC/yr  11999.282165
#             GEA_Mix_2C_AdvTrans_PartialDelay2020   World  Emissions|VOC kt VOC/yr  12784.348500
#             GEA_Mix_base                           World  Emissions|VOC kt VOC/yr  28380.438165
#
#                                                                                            2050  \
# model       scenario                               region variable      unit
# MESSAGE V.3 GEA_Eff_1p5C                           World  Emissions|VOC kt VOC/yr   1636.834834
#             GEA_Eff_1p5C_Delay2020                 World  Emissions|VOC kt VOC/yr    132.722333
#             GEA_Eff_2C_Delay2020                   World  Emissions|VOC kt VOC/yr   5701.531000
#             GEA_Eff_AdvNCO2_1p5C                   World  Emissions|VOC kt VOC/yr   3034.419666
#             GEA_Eff_base                           World  Emissions|VOC kt VOC/yr  22663.595165
#             GEA_Mix_1p5C_AdvNCO2_PartialDelay2020  World  Emissions|VOC kt VOC/yr    346.010500
#             GEA_Mix_1p5C_AdvTrans_PartialDelay2020 World  Emissions|VOC kt VOC/yr    718.232166
#             GEA_Mix_2C_AdvNCO2_PartialDelay2020    World  Emissions|VOC kt VOC/yr   5203.671000
#             GEA_Mix_2C_AdvTrans_PartialDelay2020   World  Emissions|VOC kt VOC/yr   5666.398835
#             GEA_Mix_base                           World  Emissions|VOC kt VOC/yr  31752.521165
#
#                                                                                            2060  \
# model       scenario                               region variable      unit
# MESSAGE V.3 GEA_Eff_1p5C                           World  Emissions|VOC kt VOC/yr   -547.818333
#             GEA_Eff_1p5C_Delay2020                 World  Emissions|VOC kt VOC/yr  -3041.784167
#             GEA_Eff_2C_Delay2020                   World  Emissions|VOC kt VOC/yr    728.339333
#             GEA_Eff_AdvNCO2_1p5C                   World  Emissions|VOC kt VOC/yr    -87.006333
#             GEA_Eff_base                           World  Emissions|VOC kt VOC/yr  23917.681335
#             GEA_Mix_1p5C_AdvNCO2_PartialDelay2020  World  Emissions|VOC kt VOC/yr  -2685.651834
#             GEA_Mix_1p5C_AdvTrans_PartialDelay2020 World  Emissions|VOC kt VOC/yr  -3026.694000
#             GEA_Mix_2C_AdvNCO2_PartialDelay2020    World  Emissions|VOC kt VOC/yr   1101.156834
#             GEA_Mix_2C_AdvTrans_PartialDelay2020   World  Emissions|VOC kt VOC/yr    669.434333
#             GEA_Mix_base                           World  Emissions|VOC kt VOC/yr  35271.760335
#
#                                                                                            2070  \
# model       scenario                               region variable      unit
# MESSAGE V.3 GEA_Eff_1p5C                           World  Emissions|VOC kt VOC/yr  -2622.044333
#             GEA_Eff_1p5C_Delay2020                 World  Emissions|VOC kt VOC/yr  -5057.462665
#             GEA_Eff_2C_Delay2020                   World  Emissions|VOC kt VOC/yr  -2589.330334
#             GEA_Eff_AdvNCO2_1p5C                   World  Emissions|VOC kt VOC/yr  -2482.811833
#             GEA_Eff_base                           World  Emissions|VOC kt VOC/yr  24540.523335
#             GEA_Mix_1p5C_AdvNCO2_PartialDelay2020  World  Emissions|VOC kt VOC/yr  -4045.633166
#             GEA_Mix_1p5C_AdvTrans_PartialDelay2020 World  Emissions|VOC kt VOC/yr  -5093.366665
#             GEA_Mix_2C_AdvNCO2_PartialDelay2020    World  Emissions|VOC kt VOC/yr  -1557.044500
#             GEA_Mix_2C_AdvTrans_PartialDelay2020   World  Emissions|VOC kt VOC/yr  -2590.034334
#             GEA_Mix_base                           World  Emissions|VOC kt VOC/yr  36792.123500
#
#                                                                                            2080  \
# model       scenario                               region variable      unit
# MESSAGE V.3 GEA_Eff_1p5C                           World  Emissions|VOC kt VOC/yr  -4616.813667
#             GEA_Eff_1p5C_Delay2020                 World  Emissions|VOC kt VOC/yr  -6491.723335
#             GEA_Eff_2C_Delay2020                   World  Emissions|VOC kt VOC/yr  -4970.351833
#             GEA_Eff_AdvNCO2_1p5C                   World  Emissions|VOC kt VOC/yr  -4673.571834
#             GEA_Eff_base                           World  Emissions|VOC kt VOC/yr  23913.475665
#             GEA_Mix_1p5C_AdvNCO2_PartialDelay2020  World  Emissions|VOC kt VOC/yr  -4893.663500
#             GEA_Mix_1p5C_AdvTrans_PartialDelay2020 World  Emissions|VOC kt VOC/yr  -6489.560000
#             GEA_Mix_2C_AdvNCO2_PartialDelay2020    World  Emissions|VOC kt VOC/yr  -3198.906334
#             GEA_Mix_2C_AdvTrans_PartialDelay2020   World  Emissions|VOC kt VOC/yr  -4786.969000
#             GEA_Mix_base                           World  Emissions|VOC kt VOC/yr  36273.229665
#
#                                                                                            2090  \
# model       scenario                               region variable      unit
# MESSAGE V.3 GEA_Eff_1p5C                           World  Emissions|VOC kt VOC/yr  -6528.056335
#             GEA_Eff_1p5C_Delay2020                 World  Emissions|VOC kt VOC/yr  -7388.854000
#             GEA_Eff_2C_Delay2020                   World  Emissions|VOC kt VOC/yr  -6382.049665
#             GEA_Eff_AdvNCO2_1p5C                   World  Emissions|VOC kt VOC/yr  -6961.251000
#             GEA_Eff_base                           World  Emissions|VOC kt VOC/yr  23039.098500
#             GEA_Mix_1p5C_AdvNCO2_PartialDelay2020  World  Emissions|VOC kt VOC/yr  -5396.620165
#             GEA_Mix_1p5C_AdvTrans_PartialDelay2020 World  Emissions|VOC kt VOC/yr  -7495.174500
#             GEA_Mix_2C_AdvNCO2_PartialDelay2020    World  Emissions|VOC kt VOC/yr  -4532.641666
#             GEA_Mix_2C_AdvTrans_PartialDelay2020   World  Emissions|VOC kt VOC/yr  -6488.652500
#             GEA_Mix_base                           World  Emissions|VOC kt VOC/yr  32766.096000
#
#                                                                                            2100
# model       scenario                               region variable      unit
# MESSAGE V.3 GEA_Eff_1p5C                           World  Emissions|VOC kt VOC/yr  -8208.009335
#             GEA_Eff_1p5C_Delay2020                 World  Emissions|VOC kt VOC/yr  -8177.840000
#             GEA_Eff_2C_Delay2020                   World  Emissions|VOC kt VOC/yr  -7798.259335
#             GEA_Eff_AdvNCO2_1p5C                   World  Emissions|VOC kt VOC/yr  -8934.667500
#             GEA_Eff_base                           World  Emissions|VOC kt VOC/yr  22275.216335
#             GEA_Mix_1p5C_AdvNCO2_PartialDelay2020  World  Emissions|VOC kt VOC/yr  -6009.307335
#             GEA_Mix_1p5C_AdvTrans_PartialDelay2020 World  Emissions|VOC kt VOC/yr  -8345.835665
#             GEA_Mix_2C_AdvNCO2_PartialDelay2020    World  Emissions|VOC kt VOC/yr  -5547.131335
#             GEA_Mix_2C_AdvTrans_PartialDelay2020   World  Emissions|VOC kt VOC/yr  -7915.150835
#             GEA_Mix_base                           World  Emissions|VOC kt VOC/yr  28284.939835

# %%
to_infill.timeseries()
# Out:
#                                                                        2005  \
# model       scenario     region variable            unit
# MESSAGE V.3 GEA_Eff_1p5C World  Emissions|BC        Mt BC/yr       7.131706
#                                 Emissions|CH4       Mt CH4/yr    326.310322
#                                 Emissions|CO        Mt CO/yr     927.965625
#                                 Emissions|CO2       Mt CO2/yr  34590.578000
#                                 Emissions|CO2|AFOLU Mt CO2/yr   3774.906667
# ...                                                                     ...
#             GEA_Mix_base World  Emissions|NOx       Mt NO2/yr     95.125347
#                                 Emissions|OC        Mt OC/yr      34.216967
#                                 Emissions|SF6       kt SF6/yr      2.499653
#                                 Emissions|Sulfur    Mt SO2/yr     90.943858
#                                 Emissions|VOC       Mt VOC/yr    192.933212
#
#                                                                        2010  \
# model       scenario     region variable            unit
# MESSAGE V.3 GEA_Eff_1p5C World  Emissions|BC        Mt BC/yr       6.751640
#                                 Emissions|CH4       Mt CH4/yr    354.122638
#                                 Emissions|CO        Mt CO/yr     875.548865
#                                 Emissions|CO2       Mt CO2/yr  36307.241670
#                                 Emissions|CO2|AFOLU Mt CO2/yr   3589.806000
# ...                                                                     ...
#             GEA_Mix_base World  Emissions|NOx       Mt NO2/yr     94.920070
#                                 Emissions|OC        Mt OC/yr      31.713185
#                                 Emissions|SF6       kt SF6/yr      2.687671
#                                 Emissions|Sulfur    Mt SO2/yr     82.682245
#                                 Emissions|VOC       Mt VOC/yr    187.060689
#
#                                                                        2020  \
# model       scenario     region variable            unit
# MESSAGE V.3 GEA_Eff_1p5C World  Emissions|BC        Mt BC/yr       5.306826
#                                 Emissions|CH4       Mt CH4/yr    331.142630
#                                 Emissions|CO        Mt CO/yr     779.657492
#                                 Emissions|CO2       Mt CO2/yr  26883.813000
#                                 Emissions|CO2|AFOLU Mt CO2/yr   2932.996000
# ...                                                                     ...
#             GEA_Mix_base World  Emissions|NOx       Mt NO2/yr    103.079891
#                                 Emissions|OC        Mt OC/yr      30.501702
#                                 Emissions|SF6       kt SF6/yr      2.196466
#                                 Emissions|Sulfur    Mt SO2/yr     84.237162
#                                 Emissions|VOC       Mt VOC/yr    192.943513
#
#                                                                        2030  \
# model       scenario     region variable            unit
# MESSAGE V.3 GEA_Eff_1p5C World  Emissions|BC        Mt BC/yr       3.986706
#                                 Emissions|CH4       Mt CH4/yr    319.303038
#                                 Emissions|CO        Mt CO/yr     662.103044
#                                 Emissions|CO2       Mt CO2/yr  16972.442670
#                                 Emissions|CO2|AFOLU Mt CO2/yr   1920.794333
# ...                                                                     ...
#             GEA_Mix_base World  Emissions|NOx       Mt NO2/yr    108.776924
#                                 Emissions|OC        Mt OC/yr      27.291162
#                                 Emissions|SF6       kt SF6/yr      1.604073
#                                 Emissions|Sulfur    Mt SO2/yr     82.469606
#                                 Emissions|VOC       Mt VOC/yr    188.637020
#
#                                                                       2040  \
# model       scenario     region variable            unit
# MESSAGE V.3 GEA_Eff_1p5C World  Emissions|BC        Mt BC/yr      3.114593
#                                 Emissions|CH4       Mt CH4/yr   326.520141
#                                 Emissions|CO        Mt CO/yr    566.561223
#                                 Emissions|CO2       Mt CO2/yr  9333.837333
#                                 Emissions|CO2|AFOLU Mt CO2/yr   454.985667
# ...                                                                    ...
#             GEA_Mix_base World  Emissions|NOx       Mt NO2/yr   103.630225
#                                 Emissions|OC        Mt OC/yr     25.157821
#                                 Emissions|SF6       kt SF6/yr     1.703709
#                                 Emissions|Sulfur    Mt SO2/yr    69.087098
#                                 Emissions|VOC       Mt VOC/yr   188.741928
#
#                                                                       2050  \
# model       scenario     region variable            unit
# MESSAGE V.3 GEA_Eff_1p5C World  Emissions|BC        Mt BC/yr      2.644808
#                                 Emissions|CH4       Mt CH4/yr   309.414794
#                                 Emissions|CO        Mt CO/yr    456.871229
#                                 Emissions|CO2       Mt CO2/yr  3273.669667
#                                 Emissions|CO2|AFOLU Mt CO2/yr -1249.138000
# ...                                                                    ...
#             GEA_Mix_base World  Emissions|NOx       Mt NO2/yr   100.556784
#                                 Emissions|OC        Mt OC/yr     22.812843
#                                 Emissions|SF6       kt SF6/yr     1.443307
#                                 Emissions|Sulfur    Mt SO2/yr    62.837438
#                                 Emissions|VOC       Mt VOC/yr   177.178846
#
#                                                                       2060  \
# model       scenario     region variable            unit
# MESSAGE V.3 GEA_Eff_1p5C World  Emissions|BC        Mt BC/yr      2.348610
#                                 Emissions|CH4       Mt CH4/yr   284.358133
#                                 Emissions|CO        Mt CO/yr    378.639662
#                                 Emissions|CO2       Mt CO2/yr -1095.636667
#                                 Emissions|CO2|AFOLU Mt CO2/yr -3081.026667
# ...                                                                    ...
#             GEA_Mix_base World  Emissions|NOx       Mt NO2/yr    91.240617
#                                 Emissions|OC        Mt OC/yr     19.949807
#                                 Emissions|SF6       kt SF6/yr     1.752369
#                                 Emissions|Sulfur    Mt SO2/yr    55.965056
#                                 Emissions|VOC       Mt VOC/yr   166.381040
#
#                                                                       2070  \
# model       scenario     region variable            unit
# MESSAGE V.3 GEA_Eff_1p5C World  Emissions|BC        Mt BC/yr      2.168220
#                                 Emissions|CH4       Mt CH4/yr   263.450999
#                                 Emissions|CO        Mt CO/yr    340.533677
#                                 Emissions|CO2       Mt CO2/yr -5244.088667
#                                 Emissions|CO2|AFOLU Mt CO2/yr -4812.650333
# ...                                                                    ...
#             GEA_Mix_base World  Emissions|NOx       Mt NO2/yr    68.173543
#                                 Emissions|OC        Mt OC/yr     17.599537
#                                 Emissions|SF6       kt SF6/yr     1.244057
#                                 Emissions|Sulfur    Mt SO2/yr    49.350265
#                                 Emissions|VOC       Mt VOC/yr   156.070879
#
#                                                                       2080  \
# model       scenario     region variable            unit
# MESSAGE V.3 GEA_Eff_1p5C World  Emissions|BC        Mt BC/yr      1.968333
#                                 Emissions|CH4       Mt CH4/yr   252.838489
#                                 Emissions|CO        Mt CO/yr    307.947706
#                                 Emissions|CO2       Mt CO2/yr -9233.627333
#                                 Emissions|CO2|AFOLU Mt CO2/yr -5902.464333
# ...                                                                    ...
#             GEA_Mix_base World  Emissions|NOx       Mt NO2/yr    63.529774
#                                 Emissions|OC        Mt OC/yr     16.022894
#                                 Emissions|SF6       kt SF6/yr     1.250147
#                                 Emissions|Sulfur    Mt SO2/yr    41.886917
#                                 Emissions|VOC       Mt VOC/yr   154.804862
#
#                                                                        2090  \
# model       scenario     region variable            unit
# MESSAGE V.3 GEA_Eff_1p5C World  Emissions|BC        Mt BC/yr       1.799467
#                                 Emissions|CH4       Mt CH4/yr    248.935841
#                                 Emissions|CO        Mt CO/yr     278.945485
#                                 Emissions|CO2       Mt CO2/yr -13056.112670
#                                 Emissions|CO2|AFOLU Mt CO2/yr  -6938.968667
# ...                                                                     ...
#             GEA_Mix_base World  Emissions|NOx       Mt NO2/yr     49.047056
#                                 Emissions|OC        Mt OC/yr      14.759442
#                                 Emissions|SF6       kt SF6/yr      1.295401
#                                 Emissions|Sulfur    Mt SO2/yr     34.984619
#                                 Emissions|VOC       Mt VOC/yr    147.500484
#
#                                                                        2100
# model       scenario     region variable            unit
# MESSAGE V.3 GEA_Eff_1p5C World  Emissions|BC        Mt BC/yr       1.682067
#                                 Emissions|CH4       Mt CH4/yr    251.052457
#                                 Emissions|CO        Mt CO/yr     254.733768
#                                 Emissions|CO2       Mt CO2/yr -16416.018670
#                                 Emissions|CO2|AFOLU Mt CO2/yr  -8005.994333
# ...                                                                     ...
#             GEA_Mix_base World  Emissions|NOx       Mt NO2/yr     46.958226
#                                 Emissions|OC        Mt OC/yr      14.012162
#                                 Emissions|SF6       kt SF6/yr      1.576726
#                                 Emissions|Sulfur    Mt SO2/yr     29.510961
#                                 Emissions|VOC       Mt VOC/yr    141.334218
#
# [183 rows x 11 columns]

# %%
# NBVAL_IGNORE_OUTPUT
pkwargs = {"color": "scenario", "linewidth": 2}

fig = plt.figure(figsize=(16, 9))
ax = fig.add_subplot(111)

pyam.concat(
    [infilled, to_infill.filter(variable="*CO2")]
).line_plot(
    ax=ax, 
    color="scenario", 
    linestyle="variable", 
    legend=True,
)
ax.set_title("Database HFC and lead emissions timeseries");

# %% [markdown]
# ### SSP-specific relationship
#
# This cruncher pre-filters the data to such that it only uses data from scenarios containing a specified string (typically scenarios which start with "SSP"). It then uses the Rolling Window Quantile cruncher as its workhorse.

# %%
print(silicone.database_crunchers.DatabaseCruncherSSPSpecificRelation.__doc__)
# Out:
#     Database cruncher which pre-filters to only use data from specific scenarios, then
#     makes a linear interpolator to return values from that set of scenarios. Uses mean
#     values in the case of repeated leader values. Returns the follower values at the
#     extreme leader values for leader values more extreme than that found in the input
#     data.

# %% [markdown]
# #### Using only one model
#
# We will show infilling using a database comprised of data only from variants of the MESSAGE model.

# %%
sr15_data_message = sr15_data.filter(
    model=["MESSAGE*"], 
    variable=["Emissions|CO2", "Emissions|VOC", "Emissions|CH4" ,"Emissions|HCF*"]
)
sr15_data_message.models()
# Out:
# 0              MESSAGE V.3
# 1      MESSAGE-GLOBIOM 1.0
# 2    MESSAGEix-GLOBIOM 1.0
# Name: model, dtype: object

# %% [markdown]
# As we can see, variants of the MESSAGE model have submitted data for a large number of scenarios.

# %%
sr15_data_message.scenarios()
# Out:
# 0                     ADVANCE_2020_1.5C-2100
# 1                         ADVANCE_2020_Med2C
# 2                          ADVANCE_2020_WB2C
# 3                         ADVANCE_2030_Med2C
# 4                     ADVANCE_2030_Price1.5C
# 5                          ADVANCE_2030_WB2C
# 6                               ADVANCE_INDC
# 7                           ADVANCE_NoPolicy
# 8                          ADVANCE_Reference
# 9                             CD-LINKS_INDCi
# 10                              CD-LINKS_NPi
# 11                     CD-LINKS_NPi2020_1000
# 12                     CD-LINKS_NPi2020_1600
# 13                      CD-LINKS_NPi2020_400
# 14                         CD-LINKS_NoPolicy
# 15                        EMF33_1.5C_cost100
# 16                           EMF33_1.5C_full
# 17                            EMF33_Baseline
# 18                       EMF33_Med2C_cost100
# 19                          EMF33_Med2C_full
# 20                        EMF33_Med2C_limbio
# 21                       EMF33_Med2C_nobeccs
# 22                        EMF33_Med2C_nofuel
# 23                          EMF33_Med2C_none
# 24                        EMF33_WB2C_cost100
# 25                           EMF33_WB2C_full
# 26                         EMF33_WB2C_limbio
# 27                         EMF33_WB2C_nofuel
# 28                         EMF33_tax_hi_full
# 29                         EMF33_tax_hi_none
# 30                         EMF33_tax_lo_full
# 31                         EMF33_tax_lo_none
# 32                              GEA_Eff_1p5C
# 33                    GEA_Eff_1p5C_Delay2020
# 34                      GEA_Eff_2C_Delay2020
# 35                      GEA_Eff_AdvNCO2_1p5C
# 36                              GEA_Eff_base
# 37     GEA_Mix_1p5C_AdvNCO2_PartialDelay2020
# 38    GEA_Mix_1p5C_AdvTrans_PartialDelay2020
# 39       GEA_Mix_2C_AdvNCO2_PartialDelay2020
# 40      GEA_Mix_2C_AdvTrans_PartialDelay2020
# 41                              GEA_Mix_base
# 42                           LowEnergyDemand
# 43                                   SSP1-19
# 44                                   SSP1-26
# 45                                   SSP1-34
# 46                                   SSP1-45
# 47                             SSP1-Baseline
# 48                                   SSP2-19
# 49                                   SSP2-26
# 50                                   SSP2-34
# 51                                   SSP2-45
# 52                                   SSP2-60
# 53                             SSP2-Baseline
# 54                                   SSP3-34
# 55                                   SSP3-45
# 56                                   SSP3-60
# 57                             SSP3-Baseline
# Name: scenario, dtype: object

# %% [markdown]
# For our example, we will infill data using data taken only from variants of the AIM model and we are only going to infill data for variants of SSP2.

# %%
data_to_infill = sr15_data.filter(
    model=["AIM*"], 
    scenario="SSP2*",
    variable=["Emissions|CO2", "Emissions|VOC", "Emissions|CH4" ,"Emissions|HCF*"], 
    year=sr15_data_message.data["year"].unique()
)
data_to_infill.models()
# Out:
# 0    AIM/CGE 2.0
# Name: model, dtype: object

# %%
data_to_infill.scenarios()
# Out:
# 0          SSP2-19
# 1          SSP2-26
# 2          SSP2-34
# 3          SSP2-45
# 4          SSP2-60
# 5    SSP2-Baseline
# Name: scenario, dtype: object

# %% [markdown]
# Although the lineshapes for CO$_2$ (left-hand column below) look similar in the AIM and MESSAGE models, the lineshapes for VOC (right-hand column below) are very different.

# %%
# NBVAL_IGNORE_OUTPUT
pdf = pyam.concat([sr15_data_message, data_to_infill])

fig = plt.figure(figsize=(16, 9))

ax = fig.add_subplot(121)
pdf.filter(scenario="SSP2*", variable="*CO2").line_plot(ax=ax, color="scenario", linestyle="model")

ax = fig.add_subplot(122)
pdf.filter(scenario="SSP2*", variable="*VOC").line_plot(ax=ax, color="scenario", linestyle="model")

plt.tight_layout()

# %% [markdown]
# Variants of the MESSAGE model have submitted data for many scenarios, but this cruncher allows us to specify that only data from scenarios which start with SSP2 should be used.

# %%
cruncher = silicone.database_crunchers.DatabaseCruncherSSPSpecificRelation(sr15_data_message)
filler = cruncher.derive_relationship("Emissions|VOC", ["Emissions|CO2"], required_scenario="SSP2*")
infilled = filler(data_to_infill)

# %% [markdown]
# We can now compare the original data, the database which was used to derive the infilling relationship and the infilled data. We see that the infilled results result in timeseries which much more strongly resemble the timeseries in the database (i.e. the similarity in CO$_2$ emissions is now also reflected in VOC emissions). We also see that no emissions values more extreme than the range of values contained in the input database are returned by this cruncher.

# %%
# NBVAL_IGNORE_OUTPUT
pkwargs = {"color": "scenario", "linewidth": 2}
fig = plt.figure(figsize=(16, 9))

ax = fig.add_subplot(131)
data_to_infill.filter(variable="*VOC").line_plot(ax=ax, **pkwargs)
ax.set_title("Original (AIM) timeseries")

ax = fig.add_subplot(132)
infilled.line_plot(ax=ax, **pkwargs)
ax.set_title("Infilled timeseries")

ax = fig.add_subplot(133)
sr15_data_message.filter(scenario="SSP2*", variable="*VOC").line_plot(ax=ax, color="scenario")
ax.set_title("Database (MESSAGE) timeseries")

plt.tight_layout()

# %% [markdown]
# #### Multiple models
# However, if we include data from many different models, the inter-model differences often exceed the differences within models, making for rather chaotic interpolation. This is shown below

# %%
scenario_string = "SSP2*"
too_much_data = sr15_data.copy().filter(variable=["Emissions|CO2", "Emissions|VOC", "Emissions|CH4" ,"Emissions|HCF*"])\
.filter(model=["AIM*"], keep=False)
cruncher = silicone.database_crunchers.DatabaseCruncherSSPSpecificRelation(too_much_data)
filler = cruncher.derive_relationship("Emissions|VOC", ["Emissions|CO2"], required_scenario=scenario_string)
infilled = filler(data_to_infill)
wide_db = cruncher._make_wide_db(too_much_data.filter(scenario=scenario_string))
interpolator = cruncher._make_interpolator("Emissions|VOC", ["Emissions|CO2"], wide_db, "year")
interp_trendline = interpolator[2060](np.arange(-60000, 150000))

# %% [markdown]
# There is no simple function relating the CO2 and VOC trends in this case

# %%
fig = plt.figure(figsize=(16, 9))
ax = fig.add_subplot(121)
too_much_data.filter(scenario=scenario_string, variable="*VOC").line_plot(ax=ax, color="scenario")
ax.set_title("VOC trends of infiller data")
ax = fig.add_subplot(122)
plt.scatter(wide_db["Emissions|CO2"].loc[wide_db.index.get_level_values('year')==2060], 
         wide_db["Emissions|VOC"].loc[wide_db.index.get_level_values('year')==2060])
plt.xlabel("Mt CO2/yr")
plt.ylabel("Mt VOC/yr")
ax.set_title("VOC vs CO2 in 2060")

# %% [markdown]
# This means that we have uneven and non-monotonic trends in the output

# %%
# NBVAL_IGNORE_OUTPUT
pkwargs = {"color": "scenario", "linewidth": 2}
fig = plt.figure(figsize=(16, 9))
ax = fig.add_subplot(121)
plt.plot(interp_trendline)
plt.title("VOC interpolator in 2060")
plt.xlabel("Mt CO2/yr")
plt.ylabel("Mt VOC/yr")

# %%
# NBVAL_IGNORE_OUTPUT
pkwargs = {"color": "scenario", "linewidth": 2}
fig = plt.figure(figsize=(16, 9))
ax = fig.add_subplot(121)
infilled.line_plot(ax=ax, **pkwargs)
ax.set_title("Infilled VOC trends")
ax = fig.add_subplot(122)
too_much_data.filter(scenario="SSP2*", variable="*VOC", model="GCAM*").line_plot(ax=ax, color="scenario")
ax.set_title("VOC trends of infiller data")

# %% [markdown]
# This package also has a function for detecting which of a group of scenarios creates an interpolation that best matches a dataset. Using this tool, we see that the CO2-CH4 relations in some SSP2 scenarios in the AIM database (data_to_infill) are more similar to SSP3/SSP1 data from MESSAGE models (the sr15_data_ssp collection).

# %%
cruncher = silicone.database_crunchers.DatabaseCruncherSSPSpecificRelation(sr15_data_ssp)
data_to_classify_19 = data_to_infill.filter(scenario="SSP2-19")
possible_ssps = ["SSP1*", "SSP2*", "SSP3*"]
cruncher._find_matching_scenarios(data_to_classify_19, "Emissions|CH4", ["Emissions|CO2"], possible_ssps)

# %%
cruncher._find_matching_scenarios(data_to_infill.filter(scenario="SSP2-Baseline"), "Emissions|CH4", ["Emissions|CO2"], possible_ssps)

# %%
cruncher._find_matching_scenarios(data_to_infill.filter(scenario="SSP2-60"), "Emissions|CH4", ["Emissions|CO2"], possible_ssps)

# %%
cruncher._find_matching_scenarios(data_to_infill.filter(scenario="SSP2-34"), "Emissions|CH4", ["Emissions|CO2"], possible_ssps)

# %%
sr15_data_ssp.models()

# %% [markdown]
# It's also possible to break down results by models and scenarios at the same time, and to get the results back in numerical form (they are reported in increasing order of distance, so the top result is the closest). In the event that a model/scenario combination doesn't have any data, a warning is displayed and the 'distance' is reported as infinity.

# %%
possible_models = sr15_data_ssp.models()
cruncher._find_matching_scenarios(
    data_to_infill.filter(scenario="SSP2-Baseline"), "Emissions|CH4", ["Emissions|CO2"], possible_ssps, possible_models, 
    return_all_info=True
)

# %% [markdown]
# Here we see that the preference for SSP3 is fairly substantial in this case, and that data is only found for these scenarios in the MESSAGE-GLOBIOM model.
#
# In some cases, we may wish to ignore the initial differences and only look for the closest trendlines, i.e. match the differentials. This is equivalent to setting all initial values to the same number, then performing the above analysis. This can be done by setting the "use_change_not_abs" value to True:

# %%
possible_models = sr15_data_ssp.models()
cruncher._find_matching_scenarios(
    data_to_infill.filter(scenario="SSP2-Baseline"), "Emissions|CH4", ["Emissions|CO2"], possible_ssps, possible_models, 
    return_all_info=True, use_change_not_abs=True
)
